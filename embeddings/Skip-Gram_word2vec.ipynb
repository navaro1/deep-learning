# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:16, 1.94MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-4
word_counts = Counter(int_words)
total_count = len(int_words)
frequency = {word: count / total_count for word, count in word_counts.items()}
drop = {word: 1 - np.sqrt(threshold/frequency[word]) for word in word_counts}
train_words = [word for word in int_words if drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    rng = random.randint(1, window_size + 1)
    start = idx - rng if (idx - rng) > 0 else 0
    end = idx + rng
    return list(set(words[start:end+1]))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 6.4060 0.0828 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 6.2841 0.0770 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 6.1067 0.0773 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 6.0391 0.0776 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.9204 0.0783 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.8202 0.0789 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.7719 0.0776 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5728 0.0766 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4208 0.0768 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.2983 0.0762 sec/batch
# Nearest to a: controlled, that, lons, customize, zhan, second, to, alleged,
# Nearest to two: implants, inquiries, eva, solution, college, cyberbrain, goldsmith, palamas,
# Nearest to and: instinct, unjust, rule, virtuoso, misconception, magnitude, comprehend, aerospace,
# Nearest to up: list, mos, king, distinguished, meshed, jiangsu, leeds, affaire,
# Nearest to seven: descend, painter, publishing, namesake, mangled, william, he, writings,
# Nearest to with: clickable, plaster, wa, to, doubts, ladoga, were, somewhat,
# Nearest to years: or, trivia, combined, eustace, disadvantages, chromosome, so, etruscan,
# Nearest to however: pub, vint, aladi, remaking, daydream, permanent, fenrir, phenol,
# Nearest to pope: lunokhod, refueling, gitanos, drunks, ut, jewish, disrespectful, haihowak,
# Nearest to running: pel, uag, or, andaman, withholding, treatment, golconda, reliance,
# Nearest to governor: afterwards, gotha, baldr, proprietors, auk, jewelers, swallow, bambino,
# Nearest to creation: cat, danish, sculptured, clothe, restraining, kono, cooper, pagan,
# Nearest to bill: ossetia, abner, ovum, reconquered, saiyan, adjoined, newly, counting,
# Nearest to operating: metabolic, nineties, joking, diaeresis, torah, microclimates, habitability, fortunes,
# Nearest to existence: block, prinz, schiavo, fluids, collating, sternum, procession, th,
# Nearest to instance: enzyte, bloodline, home, founders, ontario, superbike, exiling, fine,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.1812 0.0780 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.0667 0.0765 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.9850 0.0768 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.9715 0.0767 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.8752 0.0773 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.8102 0.0771 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.7657 0.0772 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.7636 0.0778 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.7301 0.0775 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.6700 0.0783 sec/batch
# Nearest to a: controlled, numbers, sunday, lons, wild, front, sitting, exception,
# Nearest to two: implants, reject, inquiries, cubs, highlanders, scottish, eva, faq,
# Nearest to and: instinct, unjust, virtuoso, magnitude, comprehend, rule, raise, steroid,
# Nearest to up: list, mos, leeds, gains, distinguished, fluid, overcome, renowned,
# Nearest to seven: writings, descend, publishing, painter, mangled, namesake, william, wary,
# Nearest to with: doubts, clickable, wa, plaster, prevents, perform, livelihood, pitched,
# Nearest to years: disadvantages, combined, interaction, trivia, eustace, microbiology, etruscan, effectively,
# Nearest to however: pub, conclude, daydream, phenol, livelihoods, via, sport, aladi,
# Nearest to pope: refueling, lunokhod, jewish, drunks, arrive, gitanos, dragged, tissues,
# Nearest to running: treatment, reliance, or, compounds, pel, steel, andaman, offs,
# Nearest to governor: afterwards, gotha, proprietors, baldr, bambino, marriage, bloc, contexts,
# Nearest to creation: cat, pagan, danish, sculptured, cooper, provoked, arts, kono,
# Nearest to bill: abner, ossetia, garland, ovum, reconquered, counting, secretary, newly,
# Nearest to operating: metabolic, fortunes, torah, nineties, diaeresis, joking, habitability, revoked,
# Nearest to existence: block, fluids, procession, schiavo, th, prinz, collating, sternum,
# Nearest to instance: founders, bloodline, rna, fine, ontario, home, exiling, enzyte,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.5775 0.0790 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.6732 0.0771 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.5724 0.0774 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.6384 0.0772 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.5704 0.0776 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.6183 0.0778 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.5737 0.0774 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.5546 0.0775 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.5410 0.0775 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.5217 0.0773 sec/batch
# Nearest to a: controlled, orchestrated, numbers, wild, sobel, lons, sitting, grid,
# Nearest to two: goldsmith, cubs, implants, highlanders, vassalage, five, nursing, eva,
# Nearest to and: instinct, magnitude, virtuoso, judd, comprehend, raise, unjust, rule,
# Nearest to up: mos, list, overcome, leeds, gains, distinguished, fluid, swapped,
# Nearest to seven: publishing, painter, mangled, william, writings, descend, suffocating, namesake,
# Nearest to with: doubts, wa, clickable, plaster, prevents, livelihood, tigers, ladoga,
# Nearest to years: etruscan, combined, disadvantages, eustace, trivia, interaction, neuromuscular, chomsky,
# Nearest to however: pub, daydream, livelihoods, seperatist, conclude, phenol, reorganization, lightning,
# Nearest to pope: refueling, lunokhod, dragged, gitanos, drunks, disrespectful, lobby, jewish,
# Nearest to running: withholding, predate, compounds, treatment, andaman, reliance, sampa, pel,
# Nearest to governor: afterwards, gotha, proprietors, baldr, bambino, auk, bloc, mitigation,
# Nearest to creation: pagan, cat, sculptured, restraining, lds, provoked, cooper, arts,
# Nearest to bill: ossetia, garland, abner, nice, secretary, reconquered, ovum, licit,
# Nearest to operating: fortunes, nineties, metabolic, diaeresis, cartridge, torah, habitability, meditative,
# Nearest to existence: block, fluids, procession, sternum, collating, schiavo, prinz, quaternion,
# Nearest to instance: preexisting, republica, rna, appealing, divinity, bloodline, democracies, sixes,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.5339 0.0786 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.5257 0.0774 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.5083 0.0776 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.5082 0.0778 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.4809 0.0780 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.4844 0.0777 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.4584 0.0790 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.4211 0.0781 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.4684 0.0787 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.4554 0.0789 sec/batch
# Nearest to a: controlled, sobel, orchestrated, lons, numbers, rounds, wild, reruns,
# Nearest to two: goldsmith, cubs, five, fineness, implants, vassalage, expire, loren,
# Nearest to and: magnitude, instinct, judd, comprehend, raise, virtuoso, kite, typified,
# Nearest to up: mos, leeds, overcome, gains, fluid, distinguished, drivers, list,
# Nearest to seven: painter, william, publishing, six, mangled, suffocating, november, marvin,
# Nearest to with: doubts, clickable, wa, prevents, tigers, plaster, livelihood, psych,
# Nearest to years: etruscan, eustace, combined, trivia, neuromuscular, disadvantages, janssen, leo,
# Nearest to however: livelihoods, pub, traitors, daydream, seperatist, donohue, lightning, phenol,
# Nearest to pope: lunokhod, refueling, dragged, emanuel, gitanos, disrespectful, drunks, collingwood,
# Nearest to running: withholding, sampa, pel, predate, andaman, compounds, mailbox, reliance,
# Nearest to governor: proprietors, gotha, afterwards, baldr, auk, bambino, bloc, troll,
# Nearest to creation: sculptured, restraining, pagan, cat, clothe, lds, provoked, cooper,
# Nearest to bill: garland, ossetia, abner, nice, reconquered, secretary, ovum, paideia,
# Nearest to operating: meditative, cartridge, nineties, metabolic, diaeresis, software, fortunes, seamonkey,
# Nearest to existence: procession, fluids, block, sternum, quaternion, collating, schiavo, scotsman,
# Nearest to instance: republica, sixes, preexisting, flask, appealing, rna, democracies, divinity,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.4739 0.0791 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.4402 0.0775 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.4183 0.0786 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.4123 0.0785 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.3692 0.0771 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.4055 0.0782 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 4.3783 0.0783 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 4.3342 0.0789 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 4.3727 0.0785 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 4.3991 0.0782 sec/batch
# Nearest to a: controlled, sobel, orchestrated, lons, rounds, wild, articulation, customize,
# Nearest to two: goldsmith, five, zero, fineness, whitehead, expire, cubs, vassalage,
# Nearest to and: magnitude, judd, comprehend, drier, kite, instinct, raise, virtuoso,
# Nearest to up: leeds, mos, overcome, affaire, fluid, gains, drivers, distinguished,
# Nearest to seven: painter, guillaume, six, william, mangled, marvin, ogre, wary,
# Nearest to with: doubts, psych, tigers, wa, prevents, clickable, plaster, livelihood,
# Nearest to years: etruscan, neuromuscular, eustace, male, combined, janssen, three, congressman,
# Nearest to however: pub, traitors, seperatist, donohue, daydream, livelihoods, lightning, conclude,
# Nearest to pope: lunokhod, gitanos, dragged, refueling, emanuel, collingwood, gte, drunks,
# Nearest to running: sampa, mailbox, withholding, pel, recreations, predate, andaman, totaling,
# Nearest to governor: proprietors, baldr, gotha, afterwards, auk, bambino, troll, squads,
# Nearest to creation: pagan, restraining, clothe, sculptured, enneads, cat, provoked, lds,
# Nearest to bill: garland, ossetia, reconquered, secretary, abner, nice, paideia, licit,
# Nearest to operating: software, meditative, cartridge, diaeresis, metabolic, seamonkey, nineties, interfaces,
# Nearest to existence: procession, quaternion, fluids, sternum, block, collating, boltzmann, scotsman,
# Nearest to instance: republica, flask, preexisting, rna, sixes, appealing, revamp, hypergeometric,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 4.3954 0.0792 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 4.3837 0.0786 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 4.3291 0.0791 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 4.3674 0.0782 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 4.3324 0.0784 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 4.3464 0.0786 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 4.3514 0.0782 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 4.3409 0.0784 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 4.2710 0.0783 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 4.2774 0.0787 sec/batch
# Nearest to a: sobel, controlled, orchestrated, lons, customize, front, articulation, landmine,
# Nearest to two: goldsmith, five, fineness, zero, whitehead, three, cubs, expire,
# Nearest to and: judd, magnitude, comprehend, drier, kite, raise, rule, emphasize,
# Nearest to up: mos, leeds, overcome, drivers, affaire, trying, throttle, fluid,
# Nearest to seven: guillaume, six, marvin, painter, mangled, namesake, william, ogre,
# Nearest to with: doubts, psych, plaster, wa, tigers, prevents, clickable, jammu,
# Nearest to years: etruscan, male, eustace, three, neuromuscular, combined, deaths, frivolity,
# Nearest to however: donohue, traitors, seperatist, livelihoods, pub, daydream, tissot, reorganization,
# Nearest to pope: dragged, lunokhod, gitanos, emanuel, collingwood, bishops, refueling, drunks,
# Nearest to running: sampa, mailbox, pel, recreations, retractable, totaling, withholding, maniac,
# Nearest to governor: proprietors, gotha, afterwards, bambino, baldr, auk, squads, athanasius,
# Nearest to creation: sculptured, restraining, clothe, pagan, enneads, cat, embodying, provoked,
# Nearest to bill: secretary, garland, ossetia, abner, nice, reconquered, majapahit, licit,
# Nearest to operating: software, meditative, seamonkey, pc, cartridge, interfaces, diaeresis, nineties,
# Nearest to existence: procession, quaternion, sternum, collating, fluids, th, scotsman, schiavo,
# Nearest to instance: sixes, republica, flask, bloodline, atgm, preexisting, hypergeometric, rna,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 4.2796 0.0799 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 4.2730 0.0787 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 4.3202 0.0784 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 4.2270 0.0789 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 4.2167 0.0791 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 4.3009 0.0786 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 4.3281 0.0780 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 4.2879 0.0784 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 4.3682 0.0784 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 4.3284 0.0786 sec/batch
# Nearest to a: sobel, jeju, orchestrated, front, controlled, landmine, articulation, lons,
# Nearest to two: goldsmith, five, zero, fineness, whitehead, three, ageing, cubs,
# Nearest to and: judd, kite, drier, magnitude, comprehend, instinct, steroid, virtuoso,
# Nearest to up: leeds, mos, overcome, affaire, nk, fluid, thatched, watani,
# Nearest to seven: guillaume, six, painter, mangled, three, marvin, ogre, britannicus,
# Nearest to with: doubts, psych, hornbill, tigers, wa, cuff, jammu, sudanese,
# Nearest to years: etruscan, male, eustace, ten, neuromuscular, three, combined, perishes,
# Nearest to however: traitors, seperatist, donohue, remaking, daydream, livelihoods, dinh, tissot,
# Nearest to pope: lunokhod, gitanos, dragged, collingwood, emanuel, bishops, drunks, papal,
# Nearest to running: sampa, mailbox, totaling, eccles, recreations, pel, retractable, maniac,
# Nearest to governor: proprietors, bambino, gotha, afterwards, squads, baldr, auk, jalalabad,
# Nearest to creation: clothe, restraining, sculptured, pagan, enneads, embodying, pursuit, cat,
# Nearest to bill: garland, secretary, ossetia, abner, majapahit, paideia, nice, licit,
# Nearest to operating: software, seamonkey, meditative, interfaces, cartridge, application, windows, allocation,
# Nearest to existence: procession, quaternion, sternum, th, collating, abeken, scotsman, fluids,
# Nearest to instance: sixes, flask, hypergeometric, decomposes, atgm, potemkin, republica, preexisting,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 4.1454 0.0798 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 4.3059 0.0786 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 4.2499 0.0782 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 4.2524 0.0783 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 4.2789 0.0784 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 4.2457 0.0783 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 4.0590 0.0789 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 4.2422 0.0785 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 4.1754 0.0789 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 4.2346 0.0791 sec/batch
# Nearest to a: sobel, landmine, controlled, orchestrated, polytechnics, jeju, front, bait,
# Nearest to two: zero, five, three, goldsmith, whitehead, fineness, four, evers,
# Nearest to and: drier, kite, judd, virtuoso, magnitude, emphasize, instinct, limestone,
# Nearest to up: mos, nk, watani, affaire, overcome, intoxicated, leeds, barge,
# Nearest to seven: guillaume, six, painter, geologist, three, mangled, giuliano, four,
# Nearest to with: doubts, psych, hornbill, cuff, wa, tigers, ladoga, plaster,
# Nearest to years: male, etruscan, ten, neuromuscular, eustace, females, female, three,
# Nearest to however: traitors, donohue, seperatist, remaking, dinh, livelihoods, tissot, demosthenes,
# Nearest to pope: lunokhod, dragged, gitanos, emanuel, papal, collingwood, drunks, bishops,
# Nearest to running: sampa, totaling, mailbox, maniac, eccles, pel, recreations, withholding,
# Nearest to governor: proprietors, bambino, afterwards, squads, gotha, baldr, jalalabad, athanasius,
# Nearest to creation: clothe, restraining, sculptured, enneads, pursuit, pagan, embodying, provoked,
# Nearest to bill: garland, abner, secretary, ossetia, majapahit, paideia, nice, infantryman,
# Nearest to operating: software, seamonkey, meditative, interfaces, pc, windows, allocation, cartridge,
# Nearest to existence: sternum, procession, quaternion, collating, th, abeken, schiavo, scotsman,
# Nearest to instance: sixes, hypergeometric, decomposes, atgm, potemkin, preexisting, rna, dubbing,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 4.2238 0.0799 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 4.1910 0.0789 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 4.2393 0.0787 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.2803 0.0111 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.1925 0.0786 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.1719 0.0791 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.1605 0.0784 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.1785 0.0784 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1360 0.0790 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.1497 0.0782 sec/batch
# Nearest to a: sobel, jeju, orchestrated, polytechnics, bait, landmine, controlled, stagnated,
# Nearest to two: five, goldsmith, zero, three, whitehead, gregorian, four, fineness,
# Nearest to and: judd, drier, kite, jemima, iverson, virtuoso, comprehend, emphasize,
# Nearest to up: nk, watani, barge, mos, affaire, overcome, leeds, trying,
# Nearest to seven: guillaume, painter, six, geologist, giuliano, mangled, three, marvin,
# Nearest to with: doubts, hornbill, psych, tigers, wa, cuff, ladoga, sudanese,
# Nearest to years: etruscan, male, ten, females, eustace, perishes, age, leap,
# Nearest to however: traitors, demosthenes, tissot, seperatist, donohue, pub, dinh, remaking,
# Nearest to pope: lunokhod, papal, dragged, gitanos, emanuel, bishops, collingwood, alexius,
# Nearest to running: sampa, mailbox, maniac, eccles, walking, totaling, recreations, retractable,
# Nearest to governor: proprietors, bambino, afterwards, gotha, squads, baldr, athanasius, vested,
# Nearest to creation: restraining, clothe, sculptured, pursuit, enneads, embodying, panipat, pagan,
# Nearest to bill: garland, secretary, abner, ossetia, majapahit, paideia, nice, attorney,
# Nearest to operating: seamonkey, software, meditative, interfaces, pc, nineties, allocation, windows,
# Nearest to existence: sternum, quaternion, collating, procession, fluids, scotsman, th, arguments,
# Nearest to instance: sixes, hypergeometric, decomposes, atgm, flask, potemkin, preexisting, gloster,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.1570 0.0793 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.1242 0.0783 sec/batch
# Epoch 2/10 Iteration: 9300 Avg. Training loss: 4.1756 0.0788 sec/batch
# Epoch 2/10 Iteration: 9400 Avg. Training loss: 4.1506 0.0789 sec/batch
# Epoch 2/10 Iteration: 9500 Avg. Training loss: 4.1490 0.0790 sec/batch
# Epoch 2/10 Iteration: 9600 Avg. Training loss: 4.0270 0.0786 sec/batch
# Epoch 2/10 Iteration: 9700 Avg. Training loss: 4.1753 0.0789 sec/batch
# Epoch 2/10 Iteration: 9800 Avg. Training loss: 4.1765 0.0788 sec/batch
# Epoch 2/10 Iteration: 9900 Avg. Training loss: 4.1583 0.0794 sec/batch
# Epoch 2/10 Iteration: 10000 Avg. Training loss: 4.1522 0.0792 sec/batch
# Nearest to a: sobel, orchestrated, jeju, stagnated, polytechnics, landmine, lons, front,
# Nearest to two: goldsmith, five, zero, three, fineness, gregorian, ageing, whitehead,
# Nearest to and: judd, kite, drier, iverson, barony, emphasize, virtuoso, instinct,
# Nearest to up: barge, nk, mos, watani, trying, affaire, intoxicated, overcome,
# Nearest to seven: guillaume, six, mangled, painter, three, giuliano, phenomenally, marvin,
# Nearest to with: doubts, hornbill, tigers, psych, cuff, wa, fairclough, classmates,
# Nearest to years: male, ten, etruscan, females, age, female, eustace, three,
# Nearest to however: traitors, demosthenes, tissot, donohue, pub, reorganization, seperatist, remaking,
# Nearest to pope: lunokhod, papal, bishops, gitanos, emanuel, dragged, alexius, gte,
# Nearest to running: mailbox, maniac, sampa, eccles, walking, offs, recreations, or,
# Nearest to governor: proprietors, bambino, afterwards, gotha, norodom, squads, baldr, jalalabad,
# Nearest to creation: restraining, clothe, sculptured, pursuit, enneads, embodying, panipat, organizations,
# Nearest to bill: garland, abner, attorney, secretary, lackey, infantryman, ossetia, majapahit,
# Nearest to operating: seamonkey, software, meditative, interfaces, system, windows, nonstop, nineties,
# Nearest to existence: sternum, collating, quaternion, procession, schiavo, scotsman, identifiable, th,
# Nearest to instance: atgm, hypergeometric, decomposes, sixes, potemkin, flask, gloster, dubbing,
# Epoch 2/10 Iteration: 10100 Avg. Training loss: 4.1523 0.0800 sec/batch
# Epoch 2/10 Iteration: 10200 Avg. Training loss: 4.1263 0.0787 sec/batch
# Epoch 2/10 Iteration: 10300 Avg. Training loss: 4.1079 0.0784 sec/batch
# Epoch 2/10 Iteration: 10400 Avg. Training loss: 4.0951 0.0785 sec/batch
# Epoch 2/10 Iteration: 10500 Avg. Training loss: 4.0156 0.0790 sec/batch
# Epoch 2/10 Iteration: 10600 Avg. Training loss: 4.1095 0.0787 sec/batch
# Epoch 2/10 Iteration: 10700 Avg. Training loss: 4.0932 0.0792 sec/batch
# Epoch 2/10 Iteration: 10800 Avg. Training loss: 4.0870 0.0789 sec/batch
# Epoch 2/10 Iteration: 10900 Avg. Training loss: 4.0943 0.0784 sec/batch
# Epoch 2/10 Iteration: 11000 Avg. Training loss: 4.1183 0.0789 sec/batch
# Nearest to a: sobel, polytechnics, bait, jeju, orchestrated, lons, pantheistic, articulation,
# Nearest to two: goldsmith, five, zero, three, evers, four, fineness, ageing,
# Nearest to and: drier, judd, barony, kite, emphasize, sensitive, baumgarten, iverson,
# Nearest to up: barge, nk, acetone, mos, trying, watani, intoxicated, groomed,
# Nearest to seven: guillaume, six, giuliano, three, painter, marvin, mangled, britannicus,
# Nearest to with: doubts, hornbill, psych, tigers, plaster, cuff, sudanese, interoperate,
# Nearest to years: male, ten, age, etruscan, females, female, prevalence, eustace,
# Nearest to however: donohue, traitors, demosthenes, tissot, pub, reorganization, joaqu, remaking,
# Nearest to pope: lunokhod, papal, bishops, gitanos, dragged, emanuel, alexius, menard,
# Nearest to running: walking, mailbox, sampa, maniac, eccles, recreations, fireballs, offs,
# Nearest to governor: proprietors, bambino, afterwards, vested, norodom, executive, elects, gotha,
# Nearest to creation: restraining, clothe, embodying, pursuit, sculptured, enneads, pagan, panipat,
# Nearest to bill: garland, abner, secretary, attorney, lackey, nice, saxophonist, antics,
# Nearest to operating: seamonkey, meditative, software, system, interfaces, allocation, nineties, nonstop,
# Nearest to existence: sternum, collating, quaternion, procession, schiavo, identifiable, fluids, arguments,
# Nearest to instance: decomposes, atgm, hypergeometric, consonant, binaries, gloster, potemkin, dubbing,
# Epoch 2/10 Iteration: 11100 Avg. Training loss: 4.1334 0.0800 sec/batch
# Epoch 2/10 Iteration: 11200 Avg. Training loss: 4.1254 0.0780 sec/batch
# Epoch 2/10 Iteration: 11300 Avg. Training loss: 4.0686 0.0790 sec/batch
# Epoch 2/10 Iteration: 11400 Avg. Training loss: 4.1484 0.0795 sec/batch
# Epoch 2/10 Iteration: 11500 Avg. Training loss: 4.0677 0.0788 sec/batch
# Epoch 2/10 Iteration: 11600 Avg. Training loss: 4.1363 0.0789 sec/batch
# Epoch 2/10 Iteration: 11700 Avg. Training loss: 4.0954 0.0790 sec/batch
# Epoch 2/10 Iteration: 11800 Avg. Training loss: 4.1270 0.0796 sec/batch
# Epoch 2/10 Iteration: 11900 Avg. Training loss: 4.1340 0.0788 sec/batch
# Epoch 2/10 Iteration: 12000 Avg. Training loss: 4.0900 0.0795 sec/batch
# Nearest to a: sobel, polytechnics, orchestrated, bait, jeju, zither, amulets, pantheistic,
# Nearest to two: goldsmith, five, zero, three, evers, fineness, whitehead, four,
# Nearest to and: judd, barony, emphasize, virtuoso, baumgarten, kite, sensitive, iverson,
# Nearest to up: barge, mos, nk, acetone, affaire, trying, malamud, watani,
# Nearest to seven: six, guillaume, painter, giuliano, three, marvin, organist, mangled,
# Nearest to with: doubts, hornbill, psych, tigers, classmates, plaster, cem, cuff,
# Nearest to years: ten, male, age, females, etruscan, ago, leap, female,
# Nearest to however: donohue, tissot, traitors, demosthenes, reorganization, pub, joaqu, aught,
# Nearest to pope: lunokhod, papal, bishops, gitanos, emanuel, dragged, alexius, gte,
# Nearest to running: mailbox, sampa, maniac, walking, recreations, tutorials, kargil, datum,
# Nearest to governor: proprietors, bambino, norodom, afterwards, vested, gotha, elects, jalalabad,
# Nearest to creation: restraining, clothe, pursuit, embodying, sculptured, enneads, pagan, questions,
# Nearest to bill: garland, secretary, abner, attorney, saxophonist, antics, majapahit, lackey,
# Nearest to operating: seamonkey, system, meditative, software, interfaces, systems, nonstop, allocation,
# Nearest to existence: sternum, collating, quaternion, schiavo, arguments, procession, abeken, scotsman,
# Nearest to instance: decomposes, hypergeometric, binaries, atgm, gloster, dubbing, consonant, potemkin,
# Epoch 2/10 Iteration: 12100 Avg. Training loss: 4.0579 0.0806 sec/batch
# Epoch 2/10 Iteration: 12200 Avg. Training loss: 4.0285 0.0787 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 4.1024 0.0791 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 4.0717 0.0788 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 4.1149 0.0790 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 4.0557 0.0791 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 4.0760 0.0793 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 4.1062 0.0786 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 4.0391 0.0773 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 4.1049 0.0783 sec/batch
# Nearest to a: sobel, polytechnics, orchestrated, bait, amulets, zither, jeju, pantheistic,
# Nearest to two: zero, goldsmith, five, three, whitehead, buxtehude, evers, four,
# Nearest to and: judd, barony, emphasize, virtuoso, kite, heterotic, instinct, almenr,
# Nearest to up: barge, nk, mos, acetone, watani, affaire, groomed, trying,
# Nearest to seven: guillaume, six, painter, three, giuliano, geologist, organist, erlk,
# Nearest to with: doubts, hornbill, psych, classmates, cem, cuff, tigers, deal,
# Nearest to years: ten, male, age, etruscan, ago, females, leap, female,
# Nearest to however: tissot, demosthenes, donohue, traitors, pub, joaqu, reorganization, aught,
# Nearest to pope: papal, lunokhod, bishops, gitanos, emanuel, dragged, alexius, menard,
# Nearest to running: mailbox, maniac, sampa, walking, recreations, datum, kargil, retractable,
# Nearest to governor: proprietors, bambino, afterwards, norodom, gotha, elects, jalalabad, karzai,
# Nearest to creation: restraining, clothe, pursuit, embodying, sculptured, enneads, led, panipat,
# Nearest to bill: garland, attorney, secretary, abner, lackey, majapahit, saxophonist, antics,
# Nearest to operating: system, seamonkey, systems, meditative, allocation, interfaces, nonstop, software,
# Nearest to existence: sternum, collating, quaternion, schiavo, arguments, fluids, scotsman, boltzmann,
# Nearest to instance: hypergeometric, atgm, decomposes, preexisting, potemkin, binaries, dressers, dubbing,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 4.0639 0.0797 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 4.0078 0.0784 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 4.1115 0.0786 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 4.0786 0.0783 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 4.1422 0.0779 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 4.0629 0.0784 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 4.0659 0.0785 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 4.0890 0.0790 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 4.0682 0.0784 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 4.0874 0.0780 sec/batch
# Nearest to a: sobel, orchestrated, polytechnics, jeju, irina, pantheistic, zither, bait,
# Nearest to two: zero, goldsmith, five, three, buxtehude, ageing, fineness, evers,
# Nearest to and: barony, judd, emphasize, virtuoso, heterotic, almenr, kite, baumgarten,
# Nearest to up: barge, nk, acetone, watani, groomed, mos, affaire, malamud,
# Nearest to seven: guillaume, six, three, giuliano, erlk, painter, mangled, britannicus,
# Nearest to with: doubts, hornbill, psych, cem, classmates, sudanese, eplf, ryaku,
# Nearest to years: ten, male, ago, etruscan, age, females, leap, expectancy,
# Nearest to however: reorganization, tissot, donohue, demosthenes, traitors, joaqu, aught, phallic,
# Nearest to pope: papal, lunokhod, bishops, gitanos, emanuel, dragged, rome, menard,
# Nearest to running: mailbox, maniac, sampa, walking, datum, recreations, kargil, cpc,
# Nearest to governor: proprietors, bambino, afterwards, elects, executive, baldr, vested, norodom,
# Nearest to creation: restraining, clothe, embodying, pursuit, sculptured, led, enneads, yuen,
# Nearest to bill: attorney, secretary, lackey, majapahit, abner, garland, appointment, legislation,
# Nearest to operating: seamonkey, system, systems, pc, nonstop, meditative, software, gnome,
# Nearest to existence: sternum, collating, quaternion, schiavo, arguments, scotsman, abeken, th,
# Nearest to instance: atgm, hypergeometric, bner, decomposes, dressers, potemkin, preexisting, democracies,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 4.1087 0.0793 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 4.0638 0.0784 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 3.9896 0.0780 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 4.0217 0.0783 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 4.0480 0.0790 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 4.0171 0.0790 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 4.0761 0.0790 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 3.9796 0.0795 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 4.0018 0.0791 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 4.0804 0.0794 sec/batch
# Nearest to a: sobel, polytechnics, orchestrated, jeju, fukuyama, bait, irina, beefheart,
# Nearest to two: zero, goldsmith, five, three, buxtehude, ageing, whitehead, four,
# Nearest to and: barony, judd, virtuoso, emphasize, jemima, baumgarten, almenr, heterotic,
# Nearest to up: barge, nk, watani, riverside, striving, malamud, affaire, acetone,
# Nearest to seven: guillaume, six, giuliano, three, painter, tt, geologist, organist,
# Nearest to with: doubts, hornbill, cem, classmates, psych, sudanese, ryaku, fujian,
# Nearest to years: ten, male, etruscan, leap, ago, females, twenty, months,
# Nearest to however: demosthenes, tissot, donohue, reorganization, traitors, joaqu, aught, seperatist,
# Nearest to pope: papal, lunokhod, bishops, gitanos, emanuel, dragged, rome, alexius,
# Nearest to running: mailbox, maniac, sampa, walking, datum, recreations, cpc, torrent,
# Nearest to governor: proprietors, bambino, norodom, afterwards, elects, baldr, executive, ketcham,
# Nearest to creation: restraining, embodying, clothe, pursuit, sculptured, led, enneads, yuen,
# Nearest to bill: attorney, secretary, garland, lackey, majapahit, abner, armigerous, saxophonist,
# Nearest to operating: seamonkey, system, systems, nonstop, pc, meditative, gnome, software,
# Nearest to existence: sternum, collating, quaternion, abeken, schiavo, creator, arguments, prinz,
# Nearest to instance: hypergeometric, decomposes, alghamdi, potemkin, dressers, democracies, preexisting, atgm,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 4.0881 0.0793 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 4.1126 0.0789 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 4.1401 0.0789 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 4.0938 0.0784 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 3.9433 0.0788 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 4.0682 0.0790 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 4.0271 0.0788 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 4.0600 0.0783 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 4.0661 0.0774 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 4.0076 0.0790 sec/batch
# Nearest to a: sobel, polytechnics, jeju, bait, orchestrated, ingham, fukuyama, pantheistic,
# Nearest to two: zero, goldsmith, five, ageing, buxtehude, three, evers, fineness,
# Nearest to and: virtuoso, barony, almenr, kite, baumgarten, emphasize, judd, quux,
# Nearest to up: barge, nk, striving, watani, riverside, malamud, mos, keep,
# Nearest to seven: giuliano, six, guillaume, three, tt, aeronautical, airliner, total,
# Nearest to with: hornbill, doubts, cem, associated, psych, fujian, sudanese, classmates,
# Nearest to years: ten, male, ago, age, etruscan, females, twenty, female,
# Nearest to however: tissot, reorganization, donohue, demosthenes, aught, joaqu, leverage, traitors,
# Nearest to pope: papal, lunokhod, gitanos, bishops, emanuel, dragged, rome, irenaeus,
# Nearest to running: maniac, mailbox, sampa, walking, datum, recreations, cpc, tutorials,
# Nearest to governor: proprietors, bambino, afterwards, executive, baldr, elects, norodom, mcgregor,
# Nearest to creation: restraining, embodying, pursuit, clothe, sculptured, enneads, yuen, led,
# Nearest to bill: garland, attorney, majapahit, lackey, secretary, abner, armigerous, ironside,
# Nearest to operating: seamonkey, system, systems, windows, software, gnome, pc, nonstop,
# Nearest to existence: sternum, collating, quaternion, schiavo, abeken, creator, th, etymologically,
# Nearest to instance: hypergeometric, dressers, alghamdi, decomposes, binaries, atgm, potemkin, sixes,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 3.8661 0.0804 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 4.0852 0.0789 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 3.9886 0.0782 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 4.0185 0.0786 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 4.0382 0.0789 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 4.0159 0.0783 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 4.0764 0.0784 sec/batch
# Epoch 3/10 Iteration: 16800 Avg. Training loss: 4.0878 0.0208 sec/batch
# Epoch 3/10 Iteration: 16900 Avg. Training loss: 4.0130 0.0776 sec/batch
# Epoch 3/10 Iteration: 17000 Avg. Training loss: 4.0194 0.0783 sec/batch
# Nearest to a: sobel, jeju, polytechnics, orchestrated, bait, fukuyama, irina, infections,
# Nearest to two: zero, goldsmith, five, ageing, buxtehude, fineness, nd, evers,
# Nearest to and: barony, virtuoso, almenr, emphasize, baumgarten, kite, judd, instinct,
# Nearest to up: barge, nk, riverside, keep, watani, acetone, mos, malamud,
# Nearest to seven: giuliano, six, three, guillaume, tt, aeronautical, total, vivaldi,
# Nearest to with: doubts, cem, hornbill, sudanese, associated, classmates, eplf, fujian,
# Nearest to years: ten, male, ago, age, etruscan, female, recent, twenty,
# Nearest to however: donohue, demosthenes, reorganization, tissot, aught, joaqu, leverage, rature,
# Nearest to pope: papal, lunokhod, gitanos, bishops, emanuel, dragged, rome, menard,
# Nearest to running: maniac, mailbox, walking, sampa, datum, cpc, recreations, eccles,
# Nearest to governor: proprietors, bambino, afterwards, mcgregor, baldr, norodom, ketcham, executive,
# Nearest to creation: restraining, clothe, pursuit, embodying, sculptured, programmed, enneads, ankles,
# Nearest to bill: garland, attorney, lackey, majapahit, abner, adjoined, dialup, fawn,
# Nearest to operating: seamonkey, system, systems, gnome, software, nonstop, interfaces, pc,
# Nearest to existence: sternum, collating, quaternion, schiavo, prinz, creator, etymologically, scotsman,
# Nearest to instance: hypergeometric, dressers, binaries, potemkin, odegard, alghamdi, atgm, decomposes,
# Epoch 3/10 Iteration: 17100 Avg. Training loss: 3.9767 0.0799 sec/batch
# Epoch 3/10 Iteration: 17200 Avg. Training loss: 4.0335 0.0788 sec/batch
# Epoch 3/10 Iteration: 17300 Avg. Training loss: 3.9774 0.0790 sec/batch
# Epoch 3/10 Iteration: 17400 Avg. Training loss: 4.0086 0.0792 sec/batch
# Epoch 3/10 Iteration: 17500 Avg. Training loss: 3.9907 0.0781 sec/batch
# Epoch 3/10 Iteration: 17600 Avg. Training loss: 3.9984 0.0786 sec/batch
# Epoch 3/10 Iteration: 17700 Avg. Training loss: 4.0058 0.0787 sec/batch
# Epoch 3/10 Iteration: 17800 Avg. Training loss: 3.9950 0.0790 sec/batch
# Epoch 3/10 Iteration: 17900 Avg. Training loss: 4.0170 0.0784 sec/batch
# Epoch 3/10 Iteration: 18000 Avg. Training loss: 3.8871 0.0784 sec/batch
# Nearest to a: jeju, polytechnics, sobel, orchestrated, pantheistic, bait, ingham, hovd,
# Nearest to two: zero, five, buxtehude, goldsmith, three, ageing, four, repeaters,
# Nearest to and: almenr, barony, baumgarten, kite, emphasize, drier, virtuoso, marys,
# Nearest to up: barge, nk, watani, riverside, acetone, keep, mos, malamud,
# Nearest to seven: giuliano, three, six, total, guillaume, airliner, vivaldi, tt,
# Nearest to with: cem, doubts, sudanese, associated, hornbill, eplf, fujian, deal,
# Nearest to years: ten, male, age, ago, female, recent, twenty, females,
# Nearest to however: reorganization, donohue, joaqu, demosthenes, aught, emptied, tissot, pub,
# Nearest to pope: papal, lunokhod, gitanos, bishops, emanuel, rome, dragged, gte,
# Nearest to running: maniac, mailbox, datum, sampa, walking, cpc, cairn, recreations,
# Nearest to governor: proprietors, appointed, bambino, ketcham, executive, vested, baldr, afterwards,
# Nearest to creation: restraining, pursuit, embodying, clothe, sculptured, led, programmed, yuen,
# Nearest to bill: garland, attorney, lackey, majapahit, dialup, abner, armigerous, fawn,
# Nearest to operating: system, seamonkey, systems, gnome, nonstop, software, interfaces, windows,
# Nearest to existence: sternum, collating, quaternion, arguments, creator, schiavo, scotsman, abeken,
# Nearest to instance: hypergeometric, dressers, alghamdi, potemkin, binaries, palestinian, democracies, depositors,
# Epoch 3/10 Iteration: 18100 Avg. Training loss: 4.0214 0.0793 sec/batch
# Epoch 3/10 Iteration: 18200 Avg. Training loss: 4.0325 0.0788 sec/batch
# Epoch 3/10 Iteration: 18300 Avg. Training loss: 4.0175 0.0781 sec/batch
# Epoch 3/10 Iteration: 18400 Avg. Training loss: 4.0155 0.0787 sec/batch
# Epoch 3/10 Iteration: 18500 Avg. Training loss: 4.0200 0.0794 sec/batch
# Epoch 3/10 Iteration: 18600 Avg. Training loss: 4.0308 0.0794 sec/batch
# Epoch 3/10 Iteration: 18700 Avg. Training loss: 3.9947 0.0795 sec/batch
# Epoch 3/10 Iteration: 18800 Avg. Training loss: 3.9036 0.0788 sec/batch
# Epoch 3/10 Iteration: 18900 Avg. Training loss: 3.9024 0.0788 sec/batch
# Epoch 3/10 Iteration: 19000 Avg. Training loss: 3.9700 0.0788 sec/batch
# Nearest to a: polytechnics, sobel, jeju, bait, pantheistic, orchestrated, hovd, lons,
# Nearest to two: zero, five, buxtehude, goldsmith, three, unpaved, ageing, repeaters,
# Nearest to and: almenr, barony, baumgarten, drier, emphasize, virtuoso, kite, instinct,
# Nearest to up: barge, nk, acetone, watani, keep, riverside, groomed, mos,
# Nearest to seven: giuliano, six, guillaume, three, total, airliner, tt, estimating,
# Nearest to with: associated, hornbill, deal, cem, doubts, sudanese, fujian, eplf,
# Nearest to years: ten, male, ago, age, recent, twenty, thirty, months,
# Nearest to however: reorganization, donohue, joaqu, pub, aught, demosthenes, emptied, tasted,
# Nearest to pope: papal, lunokhod, bishops, gitanos, emanuel, dragged, rome, gte,
# Nearest to running: maniac, mailbox, walking, datum, cpc, sampa, cairn, currying,
# Nearest to governor: proprietors, appointed, bambino, vested, executive, elects, norodom, ketcham,
# Nearest to creation: restraining, pursuit, clothe, embodying, programmed, led, yuen, sculptured,
# Nearest to bill: garland, attorney, lackey, majapahit, abner, ironside, fawn, saxophonist,
# Nearest to operating: system, seamonkey, systems, nonstop, software, tasks, gnome, interfaces,
# Nearest to existence: sternum, collating, quaternion, arguments, creator, prinz, schiavo, abeken,
# Nearest to instance: hypergeometric, binaries, dressers, bner, distributive, alghamdi, potemkin, odegard,
# Epoch 3/10 Iteration: 19100 Avg. Training loss: 3.9656 0.0798 sec/batch
# Epoch 3/10 Iteration: 19200 Avg. Training loss: 3.9862 0.0792 sec/batch
# Epoch 3/10 Iteration: 19300 Avg. Training loss: 3.9228 0.0789 sec/batch
# Epoch 3/10 Iteration: 19400 Avg. Training loss: 3.9998 0.0788 sec/batch
# Epoch 3/10 Iteration: 19500 Avg. Training loss: 3.9849 0.0786 sec/batch
# Epoch 3/10 Iteration: 19600 Avg. Training loss: 4.0075 0.0786 sec/batch
# Epoch 3/10 Iteration: 19700 Avg. Training loss: 3.9808 0.0784 sec/batch
# Epoch 3/10 Iteration: 19800 Avg. Training loss: 4.0231 0.0788 sec/batch
# Epoch 3/10 Iteration: 19900 Avg. Training loss: 3.9234 0.0781 sec/batch
# Epoch 3/10 Iteration: 20000 Avg. Training loss: 3.9714 0.0782 sec/batch
# Nearest to a: sobel, polytechnics, jeju, pantheistic, hovd, irina, orchestrated, bait,
# Nearest to two: zero, goldsmith, five, nd, buxtehude, three, ageing, repeaters,
# Nearest to and: barony, almenr, judd, baumgarten, virtuoso, instinct, quux, heterotic,
# Nearest to up: nk, barge, acetone, mos, malamud, keep, synthase, meshed,
# Nearest to seven: giuliano, six, guillaume, three, vivaldi, tt, aeronautical, nine,
# Nearest to with: associated, deal, hornbill, doubts, cem, fujian, classmates, eplf,
# Nearest to years: ten, ago, male, age, twenty, thirty, recent, months,
# Nearest to however: aught, donohue, joaqu, reorganization, pub, tasted, emptied, tissot,
# Nearest to pope: papal, bishops, lunokhod, gitanos, emanuel, rome, dragged, irenaeus,
# Nearest to running: maniac, mailbox, walking, datum, sampa, cpc, programmability, recreations,
# Nearest to governor: proprietors, appointed, bambino, norodom, baldr, vested, ketcham, executive,
# Nearest to creation: restraining, pursuit, embodying, clothe, programmed, led, yuen, sculptured,
# Nearest to bill: garland, lackey, attorney, majapahit, ironside, armigerous, scott, abner,
# Nearest to operating: system, seamonkey, systems, tasks, nonstop, software, gnome, interfaces,
# Nearest to existence: sternum, collating, quaternion, creator, arguments, schiavo, prinz, accumulation,
# Nearest to instance: hypergeometric, binaries, bner, alghamdi, dressers, odegard, distributive, potemkin,
# Epoch 3/10 Iteration: 20100 Avg. Training loss: 3.9910 0.0792 sec/batch
# Epoch 3/10 Iteration: 20200 Avg. Training loss: 4.0167 0.0795 sec/batch
# Epoch 3/10 Iteration: 20300 Avg. Training loss: 4.0343 0.0785 sec/batch
# Epoch 3/10 Iteration: 20400 Avg. Training loss: 4.0009 0.0790 sec/batch
# Epoch 3/10 Iteration: 20500 Avg. Training loss: 3.9465 0.0790 sec/batch
# Epoch 3/10 Iteration: 20600 Avg. Training loss: 3.9260 0.0789 sec/batch
# Epoch 3/10 Iteration: 20700 Avg. Training loss: 3.9929 0.0789 sec/batch
# Epoch 3/10 Iteration: 20800 Avg. Training loss: 3.9814 0.0795 sec/batch
# Epoch 3/10 Iteration: 20900 Avg. Training loss: 4.0080 0.0798 sec/batch
# Epoch 3/10 Iteration: 21000 Avg. Training loss: 3.9529 0.0798 sec/batch
# Nearest to a: sobel, polytechnics, pantheistic, jeju, orchestrated, irina, hovd, subservient,
# Nearest to two: zero, goldsmith, buxtehude, five, nd, ageing, three, evers,
# Nearest to and: almenr, barony, baumgarten, judd, virtuoso, kite, instinct, emphasize,
# Nearest to up: barge, acetone, malamud, nk, mos, keep, groomed, neurophysiology,
# Nearest to seven: giuliano, six, vivaldi, three, guillaume, nine, estimating, erlk,
# Nearest to with: associated, cem, deal, doubts, classmates, fujian, hornbill, sudanese,
# Nearest to years: ago, ten, male, age, thirty, recent, twenty, female,
# Nearest to however: joaqu, pub, donohue, aught, reorganization, tasted, demosthenes, susa,
# Nearest to pope: papal, bishops, lunokhod, gitanos, emanuel, dragged, rome, irenaeus,
# Nearest to running: maniac, mailbox, walking, datum, cpc, sampa, recreations, programmability,
# Nearest to governor: proprietors, appointed, bambino, karzai, baldr, norodom, puttnam, executive,
# Nearest to creation: restraining, pursuit, clothe, programmed, embodying, led, yuen, sculptured,
# Nearest to bill: garland, lackey, attorney, ironside, majapahit, armigerous, abner, minimax,
# Nearest to operating: system, seamonkey, systems, nonstop, codd, tasks, allocation, software,
# Nearest to existence: sternum, collating, creator, quaternion, arguments, schiavo, prinz, abeken,
# Nearest to instance: hypergeometric, potemkin, dressers, alghamdi, bner, democracies, binaries, preexisting,
# Epoch 3/10 Iteration: 21100 Avg. Training loss: 3.9588 0.0800 sec/batch
# Epoch 3/10 Iteration: 21200 Avg. Training loss: 4.0207 0.0792 sec/batch
# Epoch 3/10 Iteration: 21300 Avg. Training loss: 3.9314 0.0782 sec/batch
# Epoch 3/10 Iteration: 21400 Avg. Training loss: 4.0280 0.0789 sec/batch
# Epoch 3/10 Iteration: 21500 Avg. Training loss: 3.9824 0.0800 sec/batch
# Epoch 3/10 Iteration: 21600 Avg. Training loss: 3.8899 0.0772 sec/batch
# Epoch 3/10 Iteration: 21700 Avg. Training loss: 4.0225 0.0768 sec/batch
# Epoch 3/10 Iteration: 21800 Avg. Training loss: 3.9730 0.0790 sec/batch
# Epoch 3/10 Iteration: 21900 Avg. Training loss: 4.0229 0.0792 sec/batch
# Epoch 3/10 Iteration: 22000 Avg. Training loss: 3.9911 0.0800 sec/batch
# Nearest to a: polytechnics, jeju, sobel, orchestrated, irina, hovd, infections, pantheistic,
# Nearest to two: zero, goldsmith, buxtehude, nd, ageing, five, evers, three,
# Nearest to and: almenr, barony, virtuoso, heterotic, baumgarten, kite, judd, instinct,
# Nearest to up: acetone, barge, nk, neurophysiology, malamud, mos, meshed, keep,
# Nearest to seven: giuliano, six, three, guillaume, estimating, nine, vivaldi, airliner,
# Nearest to with: associated, cem, fujian, deal, hornbill, sudanese, classmates, doubts,
# Nearest to years: ago, ten, male, age, thirty, recent, twenty, female,
# Nearest to however: joaqu, aught, pub, reorganization, emptied, donohue, tasted, rature,
# Nearest to pope: papal, bishops, gitanos, lunokhod, emanuel, dragged, rome, irenaeus,
# Nearest to running: maniac, mailbox, datum, walking, recreations, cpc, sampa, cairn,
# Nearest to governor: proprietors, appointed, bambino, karzai, chief, puttnam, norodom, executive,
# Nearest to creation: restraining, pursuit, embodying, clothe, programmed, led, yuen, yacc,
# Nearest to bill: garland, attorney, lackey, majapahit, ironside, armigerous, act, minimax,
# Nearest to operating: system, seamonkey, systems, nonstop, codd, gnome, fortunes, allocation,
# Nearest to existence: sternum, collating, quaternion, creator, arguments, schiavo, prinz, abeken,
# Nearest to instance: hypergeometric, dressers, potemkin, binaries, alghamdi, odegard, genealogical, decomposes,
# Epoch 3/10 Iteration: 22100 Avg. Training loss: 3.9630 0.0815 sec/batch
# Epoch 3/10 Iteration: 22200 Avg. Training loss: 3.9983 0.0797 sec/batch
# Epoch 3/10 Iteration: 22300 Avg. Training loss: 3.9777 0.0794 sec/batch
# Epoch 3/10 Iteration: 22400 Avg. Training loss: 4.0013 0.0793 sec/batch
# Epoch 3/10 Iteration: 22500 Avg. Training loss: 3.9825 0.0789 sec/batch
# ...
# Nearest to running: joke, decstation, maniac, ran, back, datum, clearwater, long,
# Nearest to governor: proprietors, appointed, lieutenant, lingual, bambino, jurats, appointment, advice,
# Nearest to creation: restraining, genesis, created, led, raise, angel, pivotal, umi,
# Nearest to bill: gates, hiring, bills, tariff, spearheaded, vetoes, stepney, clinton,
# Nearest to operating: system, systems, unix, seamonkey, codd, accounting, reactos, booted,
# Nearest to existence: denies, evidence, exists, creator, quaternion, qed, arguments, intellects,
# Nearest to instance: verg, for, manifesto, thicker, giorgio, gaas, hypergeometric, tauroctony,
# Epoch 10/10 Iteration: 76100 Avg. Training loss: 3.8250 0.0800 sec/batch
# Epoch 10/10 Iteration: 76200 Avg. Training loss: 3.8342 0.0778 sec/batch
# Epoch 10/10 Iteration: 76300 Avg. Training loss: 3.7977 0.0790 sec/batch
# Epoch 10/10 Iteration: 76400 Avg. Training loss: 3.8626 0.0784 sec/batch
# Epoch 10/10 Iteration: 76500 Avg. Training loss: 3.8158 0.0780 sec/batch
# Epoch 10/10 Iteration: 76600 Avg. Training loss: 3.8054 0.0785 sec/batch
# Epoch 10/10 Iteration: 76700 Avg. Training loss: 3.6897 0.0786 sec/batch
# Epoch 10/10 Iteration: 76800 Avg. Training loss: 3.8377 0.0786 sec/batch
# Epoch 10/10 Iteration: 76900 Avg. Training loss: 3.8363 0.0788 sec/batch
# Epoch 10/10 Iteration: 77000 Avg. Training loss: 3.8385 0.0783 sec/batch
# Nearest to a: polytechnics, caricom, pilsner, egos, curfew, brief, teenager, hovd,
# Nearest to two: doings, nd, satisfying, june, zero, influenced, asl, glick,
# Nearest to and: vinnie, magee, dementia, mcmartin, pani, kite, judd, murakami,
# Nearest to up: picked, grew, summed, pick, nk, mos, follow, broke,
# Nearest to seven: boeing, airliner, kwajalein, faintly, entire, merck, connexion, giuliano,
# Nearest to with: associated, confused, dealing, consistent, combined, deal, along, contact,
# Nearest to years: ago, thirty, female, male, recent, hundred, over, every,
# Nearest to however: aurora, dahl, matsui, soon, hussite, pub, saarinen, pata,
# Nearest to pope: gregory, papal, innocent, pius, papacy, assured, rome, antipope,
# Nearest to running: decstation, long, maniac, joke, ran, clearwater, back, datum,
# Nearest to governor: proprietors, appointed, lieutenant, appointment, lingual, bambino, advice, jurats,
# Nearest to creation: restraining, genesis, led, raise, created, angel, pivotal, mannus,
# Nearest to bill: gates, hiring, bills, tariff, spearheaded, sequencing, stepney, clinton,
# Nearest to operating: system, systems, unix, seamonkey, codd, booted, reactos, accounting,
# Nearest to existence: denies, evidence, exists, creator, qed, quaternion, arguments, intellects,
# Nearest to instance: for, verg, manifesto, thicker, hypergeometric, omri, giorgio, vaux,
# Epoch 10/10 Iteration: 77100 Avg. Training loss: 3.8467 0.0793 sec/batch
# Epoch 10/10 Iteration: 77200 Avg. Training loss: 3.8362 0.0795 sec/batch
# Epoch 10/10 Iteration: 77300 Avg. Training loss: 3.8504 0.0796 sec/batch
# Epoch 10/10 Iteration: 77400 Avg. Training loss: 3.8184 0.0790 sec/batch
# Epoch 10/10 Iteration: 77500 Avg. Training loss: 3.7369 0.0783 sec/batch
# Epoch 10/10 Iteration: 77600 Avg. Training loss: 3.7027 0.0790 sec/batch
# Epoch 10/10 Iteration: 77700 Avg. Training loss: 3.8059 0.0783 sec/batch
# Epoch 10/10 Iteration: 77800 Avg. Training loss: 3.7744 0.0789 sec/batch
# Epoch 10/10 Iteration: 77900 Avg. Training loss: 3.8349 0.0786 sec/batch
# Epoch 10/10 Iteration: 78000 Avg. Training loss: 3.7438 0.0788 sec/batch
# Nearest to a: polytechnics, pilsner, caricom, brief, piece, hovd, sobel, astonishingly,
# Nearest to two: nd, doings, satisfying, zero, asl, june, carcinoma, glick,
# Nearest to and: dementia, forefather, mcmartin, vinnie, magee, barony, apollinaire, transient,
# Nearest to up: picked, summed, grew, nk, pick, mos, christianised, follow,
# Nearest to seven: boeing, airliner, kwajalein, nine, faintly, connexion, merck, eastbourne,
# Nearest to with: associated, confused, dealing, consistent, combined, contact, deal, along,
# Nearest to years: ago, thirty, female, male, recent, hundred, over, decades,
# Nearest to however: aurora, matsui, dahl, hussite, pub, saarinen, does, assertions,
# Nearest to pope: gregory, papal, pius, papacy, innocent, assured, gitanos, rome,
# Nearest to running: ran, joke, long, clearwater, decstation, walking, maniac, buffalo,
# Nearest to governor: appointed, proprietors, lieutenant, appointment, lingual, jurats, bambino, advice,
# Nearest to creation: genesis, restraining, led, raise, created, pivotal, eats, umi,
# Nearest to bill: gates, hiring, bills, tariff, spearheaded, stepney, sequencing, refusal,
# Nearest to operating: system, systems, unix, seamonkey, reactos, codd, booted, accounting,
# Nearest to existence: denies, evidence, exists, creator, qed, arguments, quaternion, intellects,
# Nearest to instance: for, verg, manifesto, thicker, hypergeometric, eaten, omri, vaux,
# Epoch 10/10 Iteration: 78100 Avg. Training loss: 3.8187 0.0802 sec/batch
# Epoch 10/10 Iteration: 78200 Avg. Training loss: 3.8344 0.0808 sec/batch
# Epoch 10/10 Iteration: 78300 Avg. Training loss: 3.8324 0.0805 sec/batch
# Epoch 10/10 Iteration: 78400 Avg. Training loss: 3.8189 0.0805 sec/batch
# Epoch 10/10 Iteration: 78500 Avg. Training loss: 3.8523 0.0803 sec/batch
# Epoch 10/10 Iteration: 78600 Avg. Training loss: 3.7542 0.0808 sec/batch
# Epoch 10/10 Iteration: 78700 Avg. Training loss: 3.8243 0.0807 sec/batch
# Epoch 10/10 Iteration: 78800 Avg. Training loss: 3.8138 0.0805 sec/batch
# Epoch 10/10 Iteration: 78900 Avg. Training loss: 3.8725 0.0798 sec/batch
# Epoch 10/10 Iteration: 79000 Avg. Training loss: 3.8505 0.0807 sec/batch
# Nearest to a: brief, caricom, polytechnics, pilsner, curfew, sobel, lehrer, teenager,
# Nearest to two: nd, satisfying, doings, june, asl, glick, november, zero,
# Nearest to and: vinnie, magee, dementia, forefather, duran, judd, mcmartin, leander,
# Nearest to up: picked, grew, summed, nk, pick, mos, follow, setting,
# Nearest to seven: boeing, airliner, nine, kwajalein, faintly, melba, connexion, merck,
# Nearest to with: associated, dealing, confused, consistent, combined, deal, contact, along,
# Nearest to years: ago, thirty, female, recent, male, hundred, decades, over,
# Nearest to however: dahl, aurora, matsui, pub, hussite, saarinen, does, assertions,
# Nearest to pope: gregory, papal, innocent, papacy, pius, rome, assured, antipope,
# Nearest to running: ran, joke, back, long, maniac, decstation, datum, instructions,
# Nearest to governor: appointed, proprietors, lieutenant, appointment, bambino, lingual, jurats, representative,
# Nearest to creation: genesis, restraining, led, umi, evolution, pivotal, created, raise,
# Nearest to bill: gates, hiring, bills, tariff, spearheaded, act, clinton, refusal,
# Nearest to operating: system, systems, codd, seamonkey, unix, reactos, booted, accounting,
# Nearest to existence: denies, creator, exists, evidence, qed, intellects, arguments, quaternion,
# Nearest to instance: for, verg, manifesto, thicker, eaten, hypergeometric, omri, reserved,
# Epoch 10/10 Iteration: 79100 Avg. Training loss: 3.8247 0.0817 sec/batch
# Epoch 10/10 Iteration: 79200 Avg. Training loss: 3.7859 0.0798 sec/batch
# Epoch 10/10 Iteration: 79300 Avg. Training loss: 3.7637 0.0796 sec/batch
# Epoch 10/10 Iteration: 79400 Avg. Training loss: 3.8422 0.0807 sec/batch
# Epoch 10/10 Iteration: 79500 Avg. Training loss: 3.8167 0.0801 sec/batch
# Epoch 10/10 Iteration: 79600 Avg. Training loss: 3.8276 0.0792 sec/batch
# Epoch 10/10 Iteration: 79700 Avg. Training loss: 3.7874 0.0792 sec/batch
# Epoch 10/10 Iteration: 79800 Avg. Training loss: 3.7930 0.0793 sec/batch
# Epoch 10/10 Iteration: 79900 Avg. Training loss: 3.8718 0.0799 sec/batch
# Epoch 10/10 Iteration: 80000 Avg. Training loss: 3.7708 0.0792 sec/batch
# Nearest to a: brief, caricom, polytechnics, pilsner, sobel, astonishingly, curfew, infections,
# Nearest to two: satisfying, nd, doings, asl, zero, goldsmith, glick, june,
# Nearest to and: apollinaire, magee, dementia, pluralism, forefather, vinnie, leander, kite,
# Nearest to up: picked, summed, grew, nk, follow, pick, mos, malamud,
# Nearest to seven: boeing, nine, airliner, kwajalein, signer, connexion, melba, eastbourne,
# Nearest to with: associated, confused, dealing, combined, consistent, deal, along, contact,
# Nearest to years: ago, thirty, female, recent, hundred, male, decades, over,
# Nearest to however: matsui, dahl, aurora, hussite, pub, does, assertions, rature,
# Nearest to pope: gregory, papal, papacy, pius, rome, innocent, assured, antipope,
# Nearest to running: ran, joke, long, maniac, back, clearwater, datum, walking,
# Nearest to governor: proprietors, appointed, lieutenant, appointment, lingual, bambino, jurats, hants,
# Nearest to creation: genesis, restraining, led, created, umi, raise, pivotal, spence,
# Nearest to bill: gates, hiring, bills, act, tariff, spearheaded, clinton, refusal,
# Nearest to operating: system, systems, seamonkey, unix, reactos, codd, accounting, booted,
# Nearest to existence: denies, exists, evidence, creator, qed, quaternion, arguments, th,
# Nearest to instance: for, verg, manifesto, thicker, eaten, omri, hypergeometric, reserved,
# Epoch 10/10 Iteration: 80100 Avg. Training loss: 3.8656 0.0812 sec/batch
# Epoch 10/10 Iteration: 80200 Avg. Training loss: 3.8026 0.0796 sec/batch
# Epoch 10/10 Iteration: 80300 Avg. Training loss: 3.7421 0.0798 sec/batch
# Epoch 10/10 Iteration: 80400 Avg. Training loss: 3.8500 0.0801 sec/batch
# Epoch 10/10 Iteration: 80500 Avg. Training loss: 3.8376 0.0798 sec/batch
# Epoch 10/10 Iteration: 80600 Avg. Training loss: 3.8583 0.0798 sec/batch
# Epoch 10/10 Iteration: 80700 Avg. Training loss: 3.8200 0.0790 sec/batch
# Epoch 10/10 Iteration: 80800 Avg. Training loss: 3.7917 0.0793 sec/batch
# Epoch 10/10 Iteration: 80900 Avg. Training loss: 3.8549 0.0787 sec/batch
# Epoch 10/10 Iteration: 81000 Avg. Training loss: 3.8191 0.0789 sec/batch
# Nearest to a: caricom, brief, pilsner, deviating, lehrer, astonishingly, polytechnics, curfew,
# Nearest to two: nd, doings, satisfying, zero, asl, jost, november, goldsmith,
# Nearest to and: magee, dementia, ceremonially, apollinaire, kite, sambia, lamorna, pluralism,
# Nearest to up: picked, summed, grew, nk, pick, follow, mos, christianised,
# Nearest to seven: boeing, kwajalein, airliner, britannicus, faintly, merck, nine, entire,
# Nearest to with: associated, confused, dealing, consistent, combined, contact, along, deal,
# Nearest to years: ago, thirty, female, hundred, male, recent, over, decades,
# Nearest to however: aurora, dahl, matsui, hussite, does, saarinen, pub, soon,
# Nearest to pope: gregory, papal, papacy, rome, pius, assured, antipope, innocent,
# Nearest to running: ran, maniac, joke, long, datum, clearwater, decstation, back,
# Nearest to governor: proprietors, appointed, appointment, lieutenant, jurats, advice, representative, lingual,
# Nearest to creation: genesis, restraining, led, raise, created, pivotal, umi, silents,
# Nearest to bill: gates, bills, hiring, act, tariff, vetoes, clinton, refusal,
# Nearest to operating: system, systems, reactos, accounting, unix, seamonkey, codd, booted,
# Nearest to existence: denies, exists, evidence, creator, th, qed, quaternion, tucson,
# Nearest to instance: for, verg, manifesto, eaten, thicker, tauroctony, omri, braganza,
# Epoch 10/10 Iteration: 81100 Avg. Training loss: 3.8465 0.0804 sec/batch
# Epoch 10/10 Iteration: 81200 Avg. Training loss: 3.8388 0.0794 sec/batch
# Epoch 10/10 Iteration: 81300 Avg. Training loss: 3.8241 0.0797 sec/batch
# Epoch 10/10 Iteration: 81400 Avg. Training loss: 3.7527 0.0791 sec/batch
# Epoch 10/10 Iteration: 81500 Avg. Training loss: 3.7813 0.0791 sec/batch
# Epoch 10/10 Iteration: 81600 Avg. Training loss: 3.8103 0.0793 sec/batch
# Epoch 10/10 Iteration: 81700 Avg. Training loss: 3.7737 0.0809 sec/batch
# Epoch 10/10 Iteration: 81800 Avg. Training loss: 3.8418 0.0806 sec/batch
# Epoch 10/10 Iteration: 81900 Avg. Training loss: 3.7062 0.0798 sec/batch
# Epoch 10/10 Iteration: 82000 Avg. Training loss: 3.7750 0.0788 sec/batch
# Nearest to a: brief, caricom, polytechnics, teenager, astonishingly, pilsner, lehrer, hovd,
# Nearest to two: nd, june, doings, satisfying, march, zero, november, asl,
# Nearest to and: dementia, magee, stoned, pluralism, sambia, vinnie, apollinaire, prez,
# Nearest to up: picked, grew, summed, nk, follow, malamud, pick, broke,
# Nearest to seven: kwajalein, boeing, nine, airliner, revolutionary, signer, merck, melba,
# Nearest to with: associated, dealing, confused, combined, consistent, along, contact, deal,
# Nearest to years: ago, thirty, female, hundred, male, recent, months, decades,
# Nearest to however: matsui, aurora, dahl, does, hussite, pub, soon, assertions,
# Nearest to pope: gregory, papal, papacy, antipope, pius, innocent, rome, benedict,
# Nearest to running: ran, long, joke, indic, datum, clearwater, maniac, decstation,
# Nearest to governor: proprietors, appointed, lieutenant, appointment, jurats, queen, advice, representative,
# Nearest to creation: genesis, restraining, led, created, raise, umi, prism, pivotal,
# Nearest to bill: gates, bills, hiring, act, refusal, vetoes, clinton, tariff,
# Nearest to operating: system, systems, reactos, seamonkey, unix, accounting, codd, stockport,
# Nearest to existence: denies, evidence, exists, creator, qed, th, quaternion, prinz,
# Nearest to instance: for, verg, manifesto, thicker, omri, eaten, tauroctony, alley,
# Epoch 10/10 Iteration: 82100 Avg. Training loss: 3.8706 0.0798 sec/batch
# Epoch 10/10 Iteration: 82200 Avg. Training loss: 3.8689 0.0801 sec/batch
# Epoch 10/10 Iteration: 82300 Avg. Training loss: 3.8914 0.0785 sec/batch
# Epoch 10/10 Iteration: 82400 Avg. Training loss: 3.9024 0.0775 sec/batch
# Epoch 10/10 Iteration: 82500 Avg. Training loss: 3.8488 0.0786 sec/batch
# Epoch 10/10 Iteration: 82600 Avg. Training loss: 3.7253 0.0794 sec/batch
# Epoch 10/10 Iteration: 82700 Avg. Training loss: 3.8502 0.0796 sec/batch
# Epoch 10/10 Iteration: 82800 Avg. Training loss: 3.7664 0.0786 sec/batch
# Epoch 10/10 Iteration: 82900 Avg. Training loss: 3.7811 0.0784 sec/batch
# Epoch 10/10 Iteration: 83000 Avg. Training loss: 3.8358 0.0783 sec/batch
# Nearest to a: brief, caricom, pilsner, polytechnics, piece, egos, lehrer, astonishingly,
# Nearest to two: satisfying, doings, nd, zero, june, jost, asl, november,
# Nearest to and: dementia, magee, mcmartin, vinnie, stoned, prez, pani, transient,
# Nearest to up: picked, grew, summed, nk, follow, malamud, mos, pick,
# Nearest to seven: kwajalein, boeing, nine, airliner, faintly, merck, eastbourne, my,
# Nearest to with: associated, dealing, confused, combined, consistent, deal, along, contact,
# Nearest to years: ago, thirty, female, male, recent, hundred, decades, every,
# Nearest to however: matsui, dahl, aurora, does, hussite, saarinen, tartaglia, soon,
# Nearest to pope: papal, gregory, papacy, antipope, pius, rome, assured, benedict,
# Nearest to running: ran, decstation, maniac, long, indic, datum, kindergarten, joke,
# Nearest to governor: proprietors, appointed, lieutenant, appointment, jurats, representative, lingual, bambino,
# Nearest to creation: genesis, restraining, raise, led, umi, pivotal, created, prism,
# Nearest to bill: gates, bills, hiring, act, vetoes, refusal, tariff, stepney,
# Nearest to operating: system, systems, unix, reactos, seamonkey, codd, accounting, booted,
# Nearest to existence: denies, exists, evidence, creator, qed, th, quaternion, tucson,
# Nearest to instance: for, verg, manifesto, thicker, tauroctony, eaten, giorgio, omri,
# Epoch 10/10 Iteration: 83100 Avg. Training loss: 3.7644 0.0791 sec/batch
# Epoch 10/10 Iteration: 83200 Avg. Training loss: 3.6362 0.0789 sec/batch
# Epoch 10/10 Iteration: 83300 Avg. Training loss: 3.8644 0.0785 sec/batch
# Epoch 10/10 Iteration: 83400 Avg. Training loss: 3.7762 0.0790 sec/batch
# Epoch 10/10 Iteration: 83500 Avg. Training loss: 3.8118 0.0784 sec/batch
# Epoch 10/10 Iteration: 83600 Avg. Training loss: 3.8403 0.0784 sec/batch
# Epoch 10/10 Iteration: 83700 Avg. Training loss: 3.8305 0.0792 sec/batch
# Epoch 10/10 Iteration: 83800 Avg. Training loss: 3.8420 0.0780 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
